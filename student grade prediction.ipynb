# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
url="https://raw.githubusercontent.com/dsrscientist/dataset4/refs/heads/main/Grades.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# Many columns having the null values
# Most columns (42 out of 43) contain categorical data (probably representing course enrollments or identifiers).
# Only the CGPA column contains numerical data, which likely represents students' cumulative grade point averages.

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# CS-406	85,CS-412	 79 most null values

# %%
#Plot the null values in the heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(),cmap='viridis')
plt.show()

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %% [markdown]
# Count: There are 571 students in this dataset.
#
# Mean (Average): The average CGPA is approximately 2.95. This gives an overall idea of the performance level of the group.
#
# Standard Deviation: The standard deviation is about 0.62. This indicates how much individual CGPAs tend to deviate from the mean; a larger value means more variation among students' GPAs.
#
# Minimum: The lowest CGPA recorded is 0.80, suggesting some students are significantly below the average.
#
# 25th Percentile (Q1): 25% of students have a CGPA below 2.54. This helps identify the lower end of the performance spectrum.
#
# Median (50th Percentile or Q2): The median CGPA is 3.03, meaning half of the students have a CGPA below this value.
#
# 75th Percentile (Q3): 75% of students have a CGPA below 3.45, indicating that the top quarter of students perform better than this.
#
# Maximum: The highest CGPA in this dataset is 3.99, which is quite strong.

# %%
#ounthe CGPA values
df["CGPA"].value_counts()
# Out:
# CGPA
# 3.019    5
# 3.058    3
# 2.793    3
# 3.443    3
# 2.206    3
#         ..
# 2.555    1
# 2.042    1
# 2.634    1
# 2.053    1
# 1.753    1
# Name: count, Length: 491, dtype: int64

# %%
#Fill the null values with most frequnetly grde like Mod
df.fillna(df.mode().iloc[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Seat No.     0
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %% [markdown]
# Removed all null values and replaced with Mode

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     571 non-null    object
#  4   HS-105/12  571 non-null    object
#  5   MT-111     571 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     571 non-null    object
#  8   EL-102     571 non-null    object
#  9   EE-119     571 non-null    object
#  10  ME-107     571 non-null    object
#  11  CS-107     571 non-null    object
#  12  HS-205/20  571 non-null    object
#  13  MT-222     571 non-null    object
#  14  EE-222     571 non-null    object
#  15  MT-224     571 non-null    object
#  16  CS-210     571 non-null    object
#  17  CS-211     571 non-null    object
#  18  CS-203     571 non-null    object
# ...

# %%
# !pip install tqdm
from tqdm import tqdm
plt.figure(figsize=(15, 30))
p = 1
for col in tqdm(df.columns[1:-1]):
    if p <= 45:
        plt.subplot(15, 3, p)
        sns.countplot(x=col, data=df)
        p += 1
plt.subplots_adjust(hspace=0.7, wspace=0.2)
plt.show()
# Out:
# ...
# 100%|██████████| 41/41 [00:03<00:00, 10.29it/s]

# %% [markdown]
# Courses like HS-101 and CS-105 seem to have students performing relatively well, while subjects like PH-121, MT-111, and CS-312 may need more attention in terms of student support or curriculum adjustment to reduce lower grades and withdrawals.

# %%
#Data Prerprocessing
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes == 'object':
        df[i] = oe.fit_transform(df[i].values.reshape(-1, 1))
df.head()
# Out:
#    Seat No.  PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  \
# 0       0.0     5.0    10.0     8.0        6.0     8.0    10.0     9.0
# 1       1.0     0.0     9.0    10.0        9.0     5.0     6.0     9.0
# 2       2.0     0.0     3.0     0.0        5.0     4.0     0.0     5.0
# 3       3.0     9.0     7.0    10.0        9.0     9.0     2.0    10.0
# 4       4.0     2.0     2.0     2.0        4.0     0.0     0.0     2.0
#
#    EL-102  EE-119  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  \
# 0     8.0     5.0  ...     8.0     8.0     8.0     8.0     2.0     0.0
# 1     0.0    10.0  ...    10.0     9.0     6.0     9.0     2.0     5.0
# 2     4.0     2.0  ...     3.0     3.0     0.0     6.0     0.0     0.0
# 3     8.0     9.0  ...    10.0     6.0    10.0     8.0     5.0     3.0
# 4     4.0     0.0  ...     5.0     4.0     4.0     5.0     2.0     0.0
#
#    CS-419  CS-423  CS-412   CGPA
# 0     8.0     3.0     2.0  2.205
# 1     6.0     6.0     3.0  2.008
# ...

# %%
df.hist(bins=10,figsize=(15,15));

# %% [markdown]
# Some courses like HS-101, PH-121, and CS-105 show data that is more evenly distributed across the X-axis, suggesting a wider range of performance among students.
# Other courses, such as EE-119, MT-111, and CS-212, show more skewed distributions, where a large number of students fall into specific bins (either higher or lower), potentially reflecting that most students performed similarly in these subjects.
#
# The final chart shows the CGPA distribution for all students, with most students having a CGPA between 2.5 and 3.5. This suggests that the majority of students are performing within an average to above-average range.

# %%
#Checking the outliers in the dataset
df.plot(kind='box',subplots=True,layout=(15,3),figsize=(15,30));

# %% [markdown]
# There is outliers found in dfferent columns in the datasets like cs-406,cs-412

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(numeric_only=True), annot=True);

# %%
#Check the Skew
df.skew()
# Out:
# Seat No.     0.044342
# PH-121       0.584635
# HS-101       0.077832
# CY-105       0.965383
# HS-105/12    0.342876
# MT-111       0.477938
# CS-105       0.977089
# CS-106       0.631239
# EL-102       0.529832
# EE-119       0.616175
# ME-107       0.124749
# CS-107       0.429084
# HS-205/20    0.803608
# MT-222       0.189265
# EE-222       0.736166
# MT-224       0.434603
# CS-210       0.670833
# CS-211       0.088682
# CS-203       0.283504
# CS-214       0.033208
# EE-217       0.739961
# CS-212       0.414343
# CS-215       0.152343
# MT-331       0.665673
# EF-303       0.349495
# HS-304       0.445965
# CS-301       0.417994
# CS-302       0.614465
# TC-383       0.366286
# MT-442       0.869584
# EL-332       0.447268
# CS-318       0.336743
# CS-306       0.426478
# CS-312       0.442731
# CS-317       0.147751
# CS-403       0.601691
# CS-421       0.108350
# CS-406       1.354857
# CS-414       0.889301
# CS-419       0.449746
# CS-423       0.498233
# ...

# %% [markdown]
# More skew for CS-412,and CS-414,CS-416

# %%
#Remove the Skewness of the dataset
